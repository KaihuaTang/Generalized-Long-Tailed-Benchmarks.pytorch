# %%
from PIL import Image, ImageDraw
from io import BytesIO
import json
import joblib
import os
import requests
import random

import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from skimage import feature as skif

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, ConcatDataset

random.seed(25)

DATA_PATH = '/data4/imagenet/ILSVRC/Data/CLS-LOC/train/'
SUP_FEATURE_PATH = './features_sup/{}.torch'

# %%
# Data loader
class ImageNetSolo(Dataset):
    def __init__(self, index, data_path):
        super(ImageNetSolo, self).__init__()
        categories = os.listdir(data_path)
        names = os.listdir(os.path.join(data_path, categories[index]))
        self.category = categories[index]
        self.images = [os.path.join(DATA_PATH, categories[index], name) for name in names]
        self.transform = transforms.Compose([
                            transforms.Resize(260),
                            transforms.CenterCrop(256),
                            transforms.ToTensor(),])
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, index):
        path = self.images[index]
        with open(path, 'rb') as f:
            sample = Image.open(f).convert('RGB')
            sample = self.transform(sample)
        return sample, index
    
def get_loader(index, batch_size=256):
    dataset = ImageNetSolo(index, DATA_PATH)
    loader = data.DataLoader(dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=8)
    return loader, dataset

# %%
def get_outputs(model, index):
    # show reconstructed image
    indexes = []
    features = []
    out_paths = []
    model.eval()
    val_loader, val_data = get_loader(index=index, batch_size=32)
    img_paths = val_data.images
    category = val_data.category
    
    with torch.no_grad():
        for images, ids in val_loader:
            images = images.cuda()
            z = model(images)
            indexes.append(ids.view(-1).cpu())
            features.append(z.cpu())
        indexes = torch.cat(indexes, dim=0).numpy()
        features = torch.cat(features, dim=0).numpy()
    
    for idx in list(indexes):
        out_paths.append(img_paths[idx])
    return features, out_paths, category

# %%
def get_cluster_label(features, category, out_paths, output_dict, NUM_CLUSTER=6):
    output_dict[category] = {}
    kmeans = KMeans(n_clusters=NUM_CLUSTER).fit(features)
    for path, label in zip(out_paths, list(kmeans.labels_)):
        if label in output_dict[category]:
            output_dict[category][label].append(path)
        else:
            output_dict[category][label] = [path,]
    return output_dict

# %%
def displays_image_list(path_dict, print_number=5, num_per_line=15):
    plt.figure(figsize=(num_per_line*2,print_number*2))
    for k in range(print_number):
        lines = print_number
        for j in range(num_per_line):
            idx = k * num_per_line + j
            idx_plot = idx
            img_temp = Image.open(path_dict[k][j]).resize((64,64))
            #Image.fromarray(np.uint8((org_img[intra_label[k][j]])*255))
            ax = plt.subplot(lines, num_per_line, idx_plot+1)##控制plot位置
            plt.imshow(img_temp)

# %%
# load moco model
model = torchvision.models.resnet50(pretrained=True).cuda()
model.fc = nn.ReLU()

# %%
output_dict = {}
NUM_CLUSTER = 6
for index in range(len(os.listdir(DATA_PATH))):
    print('======== Leanring {} category ==========='.format(index))
    features, out_paths, category = get_outputs(model, index)
    output_dict = get_cluster_label(features, category, out_paths, output_dict, NUM_CLUSTER=NUM_CLUSTER)
    # save features and image paths
    torch.save({'features':features, 'paths':out_paths}, SUP_FEATURE_PATH.format(category))
torch.save(output_dict, SUP_FEATURE_PATH.format('clustering_outputs'))
# Out:
# ======== Leanring 0 category ===========
# ======== Leanring 1 category ===========
# ======== Leanring 2 category ===========
# ======== Leanring 3 category ===========
# ======== Leanring 4 category ===========
# ======== Leanring 5 category ===========
# ======== Leanring 6 category ===========
# ======== Leanring 7 category ===========
# ======== Leanring 8 category ===========
# ======== Leanring 9 category ===========
# ======== Leanring 10 category ===========
# ======== Leanring 11 category ===========
# ======== Leanring 12 category ===========
# ======== Leanring 13 category ===========
# ======== Leanring 14 category ===========
# ======== Leanring 15 category ===========
# ======== Leanring 16 category ===========
# ======== Leanring 17 category ===========
# ======== Leanring 18 category ===========
# ======== Leanring 19 category ===========
# ======== Leanring 20 category ===========
# ======== Leanring 21 category ===========
# ======== Leanring 22 category ===========
# ======== Leanring 23 category ===========
# ======== Leanring 24 category ===========
# ======== Leanring 25 category ===========
# ======== Leanring 26 category ===========
# ======== Leanring 27 category ===========
# ======== Leanring 28 category ===========
# ======== Leanring 29 category ===========
# ======== Leanring 30 category ===========
# ======== Leanring 31 category ===========
# ======== Leanring 32 category ===========
# ======== Leanring 33 category ===========
# ======== Leanring 34 category ===========
# ======== Leanring 35 category ===========
# ======== Leanring 36 category ===========
# ======== Leanring 37 category ===========
# ======== Leanring 38 category ===========
# ======== Leanring 39 category ===========
# ======== Leanring 40 category ===========
# ======== Leanring 41 category ===========
# ======== Leanring 42 category ===========
# ======== Leanring 43 category ===========
# ======== Leanring 44 category ===========
# ======== Leanring 45 category ===========
# ======== Leanring 46 category ===========
# ======== Leanring 47 category ===========
# ======== Leanring 48 category ===========
# ======== Leanring 49 category ===========
# ======== Leanring 50 category ===========
# ======== Leanring 51 category ===========
# ======== Leanring 52 category ===========
# ======== Leanring 53 category ===========
# ======== Leanring 54 category ===========
# ======== Leanring 55 category ===========
# ======== Leanring 56 category ===========
# ======== Leanring 57 category ===========
# ======== Leanring 58 category ===========
# ======== Leanring 59 category ===========
# ======== Leanring 60 category ===========
# ======== Leanring 61 category ===========
# ======== Leanring 62 category ===========
# ======== Leanring 63 category ===========
# ======== Leanring 64 category ===========
# ======== Leanring 65 category ===========
# ======== Leanring 66 category ===========
# ======== Leanring 67 category ===========
# ======== Leanring 68 category ===========
# ======== Leanring 69 category ===========
# ======== Leanring 70 category ===========
# ======== Leanring 71 category ===========
# ======== Leanring 72 category ===========
# ======== Leanring 73 category ===========
# ======== Leanring 74 category ===========
# ======== Leanring 75 category ===========
# ======== Leanring 76 category ===========
# ======== Leanring 77 category ===========
# ======== Leanring 78 category ===========
# ======== Leanring 79 category ===========
# ======== Leanring 80 category ===========
# ======== Leanring 81 category ===========
# ======== Leanring 82 category ===========
# ======== Leanring 83 category ===========
# ======== Leanring 84 category ===========
# ======== Leanring 85 category ===========
# ======== Leanring 86 category ===========
# ======== Leanring 87 category ===========
# ======== Leanring 88 category ===========
# ======== Leanring 89 category ===========
# ======== Leanring 90 category ===========
# ======== Leanring 91 category ===========
# ======== Leanring 92 category ===========
# ======== Leanring 93 category ===========
# ======== Leanring 94 category ===========
# ======== Leanring 95 category ===========
# ======== Leanring 96 category ===========
# ======== Leanring 97 category ===========
# ======== Leanring 98 category ===========
# ======== Leanring 99 category ===========
# ======== Leanring 100 category ===========
# ======== Leanring 101 category ===========
# ======== Leanring 102 category ===========
# ======== Leanring 103 category ===========
# ======== Leanring 104 category ===========
# ======== Leanring 105 category ===========
# ======== Leanring 106 category ===========
# ======== Leanring 107 category ===========
# ======== Leanring 108 category ===========
# ======== Leanring 109 category ===========
# ======== Leanring 110 category ===========
# ======== Leanring 111 category ===========
# ======== Leanring 112 category ===========
# ======== Leanring 113 category ===========
# ======== Leanring 114 category ===========
# ======== Leanring 115 category ===========
# ======== Leanring 116 category ===========
# ======== Leanring 117 category ===========
# ======== Leanring 118 category ===========
# ======== Leanring 119 category ===========
# ======== Leanring 120 category ===========
# ======== Leanring 121 category ===========
# ======== Leanring 122 category ===========
# ======== Leanring 123 category ===========
# ======== Leanring 124 category ===========
# ======== Leanring 125 category ===========
# ======== Leanring 126 category ===========
# ======== Leanring 127 category ===========
# ======== Leanring 128 category ===========
# ======== Leanring 129 category ===========
# ======== Leanring 130 category ===========
# ======== Leanring 131 category ===========
# ======== Leanring 132 category ===========
# ======== Leanring 133 category ===========
# ======== Leanring 134 category ===========
# ======== Leanring 135 category ===========
# ======== Leanring 136 category ===========
# ======== Leanring 137 category ===========
# ======== Leanring 138 category ===========
# ======== Leanring 139 category ===========
# ======== Leanring 140 category ===========
# ======== Leanring 141 category ===========
# ======== Leanring 142 category ===========
# ======== Leanring 143 category ===========
# ======== Leanring 144 category ===========
# ======== Leanring 145 category ===========
# ======== Leanring 146 category ===========
# ======== Leanring 147 category ===========
# ======== Leanring 148 category ===========
# ======== Leanring 149 category ===========
# ======== Leanring 150 category ===========
# ======== Leanring 151 category ===========
# ======== Leanring 152 category ===========
# ======== Leanring 153 category ===========
# ======== Leanring 154 category ===========
# ======== Leanring 155 category ===========
# ======== Leanring 156 category ===========
# ======== Leanring 157 category ===========
# ======== Leanring 158 category ===========
# ======== Leanring 159 category ===========
# ======== Leanring 160 category ===========
# ======== Leanring 161 category ===========
# ======== Leanring 162 category ===========
# ======== Leanring 163 category ===========
# ======== Leanring 164 category ===========
# ======== Leanring 165 category ===========
# ======== Leanring 166 category ===========
# ======== Leanring 167 category ===========
# ======== Leanring 168 category ===========
# ======== Leanring 169 category ===========
# ======== Leanring 170 category ===========
# ======== Leanring 171 category ===========
# ======== Leanring 172 category ===========
# ======== Leanring 173 category ===========
# ======== Leanring 174 category ===========
# ======== Leanring 175 category ===========
# ======== Leanring 176 category ===========
# ======== Leanring 177 category ===========
# ======== Leanring 178 category ===========
# ======== Leanring 179 category ===========
# /home/kaihua/anaconda3/envs/long-tail/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:785: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# ======== Leanring 180 category ===========
# ======== Leanring 181 category ===========
# ======== Leanring 182 category ===========
# ======== Leanring 183 category ===========
# ======== Leanring 184 category ===========
# ======== Leanring 185 category ===========
# ======== Leanring 186 category ===========
# ======== Leanring 187 category ===========
# ======== Leanring 188 category ===========
# ======== Leanring 189 category ===========
# ======== Leanring 190 category ===========
# ======== Leanring 191 category ===========
# ======== Leanring 192 category ===========
# ======== Leanring 193 category ===========
# ======== Leanring 194 category ===========
# ======== Leanring 195 category ===========
# ======== Leanring 196 category ===========
# ======== Leanring 197 category ===========
# ======== Leanring 198 category ===========
# ======== Leanring 199 category ===========
# ======== Leanring 200 category ===========
# ======== Leanring 201 category ===========
# ======== Leanring 202 category ===========
# ======== Leanring 203 category ===========
# ======== Leanring 204 category ===========
# ======== Leanring 205 category ===========
# ======== Leanring 206 category ===========
# ======== Leanring 207 category ===========
# ======== Leanring 208 category ===========
# ======== Leanring 209 category ===========
# ======== Leanring 210 category ===========
# ======== Leanring 211 category ===========
# ======== Leanring 212 category ===========
# ======== Leanring 213 category ===========
# ======== Leanring 214 category ===========
# ======== Leanring 215 category ===========
# ======== Leanring 216 category ===========
# ======== Leanring 217 category ===========
# ======== Leanring 218 category ===========
# ======== Leanring 219 category ===========
# ======== Leanring 220 category ===========
# ======== Leanring 221 category ===========
# ======== Leanring 222 category ===========
# ======== Leanring 223 category ===========
# ======== Leanring 224 category ===========
# ======== Leanring 225 category ===========
# ======== Leanring 226 category ===========
# ======== Leanring 227 category ===========
# ======== Leanring 228 category ===========
# ======== Leanring 229 category ===========
# ======== Leanring 230 category ===========
# ======== Leanring 231 category ===========
# ======== Leanring 232 category ===========
# ======== Leanring 233 category ===========
# ======== Leanring 234 category ===========
# ======== Leanring 235 category ===========
# ======== Leanring 236 category ===========
# ======== Leanring 237 category ===========
# ======== Leanring 238 category ===========
# ======== Leanring 239 category ===========
# ======== Leanring 240 category ===========
# ======== Leanring 241 category ===========
# ======== Leanring 242 category ===========
# ======== Leanring 243 category ===========
# ======== Leanring 244 category ===========
# ======== Leanring 245 category ===========
# ======== Leanring 246 category ===========
# ======== Leanring 247 category ===========
# ======== Leanring 248 category ===========
# ======== Leanring 249 category ===========
# ======== Leanring 250 category ===========
# ======== Leanring 251 category ===========
# ======== Leanring 252 category ===========
# ======== Leanring 253 category ===========
# ======== Leanring 254 category ===========
# ======== Leanring 255 category ===========
# ======== Leanring 256 category ===========
# ======== Leanring 257 category ===========
# ======== Leanring 258 category ===========
# ======== Leanring 259 category ===========
# ======== Leanring 260 category ===========
# ======== Leanring 261 category ===========
# ======== Leanring 262 category ===========
# ======== Leanring 263 category ===========
# ======== Leanring 264 category ===========
# ======== Leanring 265 category ===========
# ======== Leanring 266 category ===========
# ======== Leanring 267 category ===========
# ======== Leanring 268 category ===========
# ======== Leanring 269 category ===========
# ======== Leanring 270 category ===========
# ======== Leanring 271 category ===========
# ======== Leanring 272 category ===========
# ======== Leanring 273 category ===========
# ======== Leanring 274 category ===========
# ======== Leanring 275 category ===========
# ======== Leanring 276 category ===========
# ======== Leanring 277 category ===========
# ======== Leanring 278 category ===========
# ======== Leanring 279 category ===========
# ======== Leanring 280 category ===========
# ======== Leanring 281 category ===========
# ======== Leanring 282 category ===========
# ======== Leanring 283 category ===========
# ======== Leanring 284 category ===========
# ======== Leanring 285 category ===========
# ======== Leanring 286 category ===========
# ======== Leanring 287 category ===========
# ======== Leanring 288 category ===========
# ======== Leanring 289 category ===========
# ======== Leanring 290 category ===========
# ======== Leanring 291 category ===========
# ======== Leanring 292 category ===========
# ======== Leanring 293 category ===========
# ======== Leanring 294 category ===========
# ======== Leanring 295 category ===========
# ======== Leanring 296 category ===========
# ======== Leanring 297 category ===========
# ======== Leanring 298 category ===========
# ======== Leanring 299 category ===========
# ======== Leanring 300 category ===========
# ======== Leanring 301 category ===========
# ======== Leanring 302 category ===========
# ======== Leanring 303 category ===========
# ======== Leanring 304 category ===========
# ======== Leanring 305 category ===========
# ======== Leanring 306 category ===========
# ======== Leanring 307 category ===========
# ======== Leanring 308 category ===========
# ======== Leanring 309 category ===========
# ======== Leanring 310 category ===========
# ======== Leanring 311 category ===========
# ======== Leanring 312 category ===========
# ======== Leanring 313 category ===========
# ======== Leanring 314 category ===========
# ======== Leanring 315 category ===========
# ======== Leanring 316 category ===========
# ======== Leanring 317 category ===========
# ======== Leanring 318 category ===========
# ======== Leanring 319 category ===========
# ======== Leanring 320 category ===========
# ======== Leanring 321 category ===========
# ======== Leanring 322 category ===========
# ======== Leanring 323 category ===========
# ======== Leanring 324 category ===========
# ======== Leanring 325 category ===========
# ======== Leanring 326 category ===========
# ======== Leanring 327 category ===========
# ======== Leanring 328 category ===========
# ======== Leanring 329 category ===========
# ======== Leanring 330 category ===========
# ======== Leanring 331 category ===========
# ======== Leanring 332 category ===========
# ======== Leanring 333 category ===========
# ======== Leanring 334 category ===========
# ======== Leanring 335 category ===========
# ======== Leanring 336 category ===========
# ======== Leanring 337 category ===========
# ======== Leanring 338 category ===========
# ======== Leanring 339 category ===========
# ======== Leanring 340 category ===========
# ======== Leanring 341 category ===========
# ======== Leanring 342 category ===========
# ======== Leanring 343 category ===========
# ======== Leanring 344 category ===========
# ======== Leanring 345 category ===========
# ======== Leanring 346 category ===========
# ======== Leanring 347 category ===========
# ======== Leanring 348 category ===========
# ======== Leanring 349 category ===========
# ======== Leanring 350 category ===========
# ======== Leanring 351 category ===========
# ======== Leanring 352 category ===========
# ======== Leanring 353 category ===========
# ======== Leanring 354 category ===========
# ======== Leanring 355 category ===========
# ======== Leanring 356 category ===========
# ======== Leanring 357 category ===========
# ======== Leanring 358 category ===========
# ======== Leanring 359 category ===========
# ======== Leanring 360 category ===========
# ======== Leanring 361 category ===========
# ======== Leanring 362 category ===========
# ======== Leanring 363 category ===========
# ======== Leanring 364 category ===========
# ======== Leanring 365 category ===========
# ======== Leanring 366 category ===========
# ======== Leanring 367 category ===========
# ======== Leanring 368 category ===========
# ======== Leanring 369 category ===========
# ======== Leanring 370 category ===========
# ======== Leanring 371 category ===========
# ======== Leanring 372 category ===========
# ======== Leanring 373 category ===========
# ======== Leanring 374 category ===========
# ======== Leanring 375 category ===========
# ======== Leanring 376 category ===========
# ======== Leanring 377 category ===========
# ======== Leanring 378 category ===========
# ======== Leanring 379 category ===========
# ======== Leanring 380 category ===========
# ======== Leanring 381 category ===========
# ======== Leanring 382 category ===========
# ======== Leanring 383 category ===========
# ======== Leanring 384 category ===========
# ======== Leanring 385 category ===========
# ======== Leanring 386 category ===========
# ======== Leanring 387 category ===========
# ======== Leanring 388 category ===========
# ======== Leanring 389 category ===========
# ======== Leanring 390 category ===========
# ======== Leanring 391 category ===========
# ======== Leanring 392 category ===========
# ======== Leanring 393 category ===========
# ======== Leanring 394 category ===========
# ======== Leanring 395 category ===========
# ======== Leanring 396 category ===========
# ======== Leanring 397 category ===========
# ======== Leanring 398 category ===========
# ======== Leanring 399 category ===========
# ======== Leanring 400 category ===========
# ======== Leanring 401 category ===========
# ======== Leanring 402 category ===========
# ======== Leanring 403 category ===========
# ======== Leanring 404 category ===========
# ======== Leanring 405 category ===========
# ======== Leanring 406 category ===========
# ======== Leanring 407 category ===========
# ======== Leanring 408 category ===========
# ======== Leanring 409 category ===========
# ======== Leanring 410 category ===========
# ======== Leanring 411 category ===========
# ======== Leanring 412 category ===========
# ======== Leanring 413 category ===========
# ======== Leanring 414 category ===========
# ======== Leanring 415 category ===========
# ======== Leanring 416 category ===========
# ======== Leanring 417 category ===========
# ======== Leanring 418 category ===========
# ======== Leanring 419 category ===========
# ======== Leanring 420 category ===========
# ======== Leanring 421 category ===========
# ======== Leanring 422 category ===========
# ======== Leanring 423 category ===========
# ======== Leanring 424 category ===========
# ======== Leanring 425 category ===========
# ======== Leanring 426 category ===========
# ======== Leanring 427 category ===========
# ======== Leanring 428 category ===========
# ======== Leanring 429 category ===========
# ======== Leanring 430 category ===========
# ======== Leanring 431 category ===========
# ======== Leanring 432 category ===========
# ======== Leanring 433 category ===========
# ======== Leanring 434 category ===========
# ======== Leanring 435 category ===========
# ======== Leanring 436 category ===========
# ======== Leanring 437 category ===========
# ======== Leanring 438 category ===========
# ======== Leanring 439 category ===========
# ======== Leanring 440 category ===========
# ======== Leanring 441 category ===========
# ======== Leanring 442 category ===========
# ======== Leanring 443 category ===========
# ======== Leanring 444 category ===========
# ======== Leanring 445 category ===========
# ======== Leanring 446 category ===========
# ======== Leanring 447 category ===========
# ======== Leanring 448 category ===========
# ======== Leanring 449 category ===========
# ======== Leanring 450 category ===========
# ======== Leanring 451 category ===========
# ======== Leanring 452 category ===========
# ======== Leanring 453 category ===========
# ======== Leanring 454 category ===========
# ======== Leanring 455 category ===========
# ======== Leanring 456 category ===========
# ======== Leanring 457 category ===========
# ======== Leanring 458 category ===========
# ======== Leanring 459 category ===========
# ======== Leanring 460 category ===========
# ======== Leanring 461 category ===========
# ======== Leanring 462 category ===========
# ======== Leanring 463 category ===========
# ======== Leanring 464 category ===========
# ======== Leanring 465 category ===========
# ======== Leanring 466 category ===========
# ======== Leanring 467 category ===========
# ======== Leanring 468 category ===========
# ======== Leanring 469 category ===========
# ======== Leanring 470 category ===========
# ======== Leanring 471 category ===========
# ======== Leanring 472 category ===========
# ======== Leanring 473 category ===========
# ======== Leanring 474 category ===========
# ======== Leanring 475 category ===========
# ======== Leanring 476 category ===========
# ======== Leanring 477 category ===========
# ======== Leanring 478 category ===========
# ======== Leanring 479 category ===========
# ======== Leanring 480 category ===========
# ======== Leanring 481 category ===========
# ======== Leanring 482 category ===========
# ======== Leanring 483 category ===========
# ======== Leanring 484 category ===========
# ======== Leanring 485 category ===========
# ======== Leanring 486 category ===========
# ======== Leanring 487 category ===========
# ======== Leanring 488 category ===========
# ======== Leanring 489 category ===========
# ======== Leanring 490 category ===========
# ======== Leanring 491 category ===========
# ======== Leanring 492 category ===========
# ======== Leanring 493 category ===========
# ======== Leanring 494 category ===========
# ======== Leanring 495 category ===========
# ======== Leanring 496 category ===========
# ======== Leanring 497 category ===========
# ======== Leanring 498 category ===========
# ======== Leanring 499 category ===========
# ======== Leanring 500 category ===========
# ======== Leanring 501 category ===========
# ======== Leanring 502 category ===========
# ======== Leanring 503 category ===========
# ======== Leanring 504 category ===========
# ======== Leanring 505 category ===========
# ======== Leanring 506 category ===========
# ======== Leanring 507 category ===========
# ======== Leanring 508 category ===========
# ======== Leanring 509 category ===========
# ======== Leanring 510 category ===========
# ======== Leanring 511 category ===========
# ======== Leanring 512 category ===========
# ======== Leanring 513 category ===========
# ======== Leanring 514 category ===========
# ======== Leanring 515 category ===========
# ======== Leanring 516 category ===========
# ======== Leanring 517 category ===========
# ======== Leanring 518 category ===========
# ======== Leanring 519 category ===========
# ======== Leanring 520 category ===========
# ======== Leanring 521 category ===========
# ======== Leanring 522 category ===========
# ======== Leanring 523 category ===========
# ======== Leanring 524 category ===========
# ======== Leanring 525 category ===========
# ======== Leanring 526 category ===========
# ======== Leanring 527 category ===========
# ======== Leanring 528 category ===========
# ======== Leanring 529 category ===========
# ======== Leanring 530 category ===========
# ======== Leanring 531 category ===========
# ======== Leanring 532 category ===========
# ======== Leanring 533 category ===========
# ======== Leanring 534 category ===========
# ======== Leanring 535 category ===========
# ======== Leanring 536 category ===========
# ======== Leanring 537 category ===========
# ======== Leanring 538 category ===========
# ======== Leanring 539 category ===========
# ======== Leanring 540 category ===========
# ======== Leanring 541 category ===========
# ======== Leanring 542 category ===========
# ======== Leanring 543 category ===========
# ======== Leanring 544 category ===========
# ======== Leanring 545 category ===========
# ======== Leanring 546 category ===========
# ======== Leanring 547 category ===========
# ======== Leanring 548 category ===========
# ======== Leanring 549 category ===========
# ======== Leanring 550 category ===========
# ======== Leanring 551 category ===========
# ======== Leanring 552 category ===========
# ======== Leanring 553 category ===========
# ======== Leanring 554 category ===========
# ======== Leanring 555 category ===========
# ======== Leanring 556 category ===========
# ======== Leanring 557 category ===========
# ======== Leanring 558 category ===========
# ======== Leanring 559 category ===========
# ======== Leanring 560 category ===========
# ======== Leanring 561 category ===========
# ======== Leanring 562 category ===========
# ======== Leanring 563 category ===========
# ======== Leanring 564 category ===========
# ======== Leanring 565 category ===========
# ======== Leanring 566 category ===========
# ======== Leanring 567 category ===========
# ======== Leanring 568 category ===========
# ======== Leanring 569 category ===========
# ======== Leanring 570 category ===========
# ======== Leanring 571 category ===========
# ======== Leanring 572 category ===========
# ======== Leanring 573 category ===========
# ======== Leanring 574 category ===========
# ======== Leanring 575 category ===========
# ======== Leanring 576 category ===========
# ======== Leanring 577 category ===========
# ======== Leanring 578 category ===========
# ======== Leanring 579 category ===========
# ======== Leanring 580 category ===========
# ======== Leanring 581 category ===========
# ======== Leanring 582 category ===========
# ======== Leanring 583 category ===========
# ======== Leanring 584 category ===========
# ======== Leanring 585 category ===========
# ======== Leanring 586 category ===========
# ======== Leanring 587 category ===========
# ======== Leanring 588 category ===========
# ======== Leanring 589 category ===========
# ======== Leanring 590 category ===========
# ======== Leanring 591 category ===========
# ======== Leanring 592 category ===========
# ======== Leanring 593 category ===========
# ======== Leanring 594 category ===========
# ======== Leanring 595 category ===========
# ======== Leanring 596 category ===========
# ======== Leanring 597 category ===========
# ======== Leanring 598 category ===========
# ======== Leanring 599 category ===========
# ======== Leanring 600 category ===========
# ======== Leanring 601 category ===========
# ======== Leanring 602 category ===========
# ======== Leanring 603 category ===========
# ======== Leanring 604 category ===========
# ======== Leanring 605 category ===========
# ======== Leanring 606 category ===========
# ======== Leanring 607 category ===========
# ======== Leanring 608 category ===========
# ======== Leanring 609 category ===========
# ======== Leanring 610 category ===========
# ======== Leanring 611 category ===========
# ======== Leanring 612 category ===========
# ======== Leanring 613 category ===========
# ======== Leanring 614 category ===========
# ======== Leanring 615 category ===========
# ======== Leanring 616 category ===========
# ======== Leanring 617 category ===========
# ======== Leanring 618 category ===========
# ======== Leanring 619 category ===========
# ======== Leanring 620 category ===========
# ======== Leanring 621 category ===========
# ======== Leanring 622 category ===========
# ======== Leanring 623 category ===========
# ======== Leanring 624 category ===========
# ======== Leanring 625 category ===========
# ======== Leanring 626 category ===========
# ======== Leanring 627 category ===========
# ======== Leanring 628 category ===========
# ======== Leanring 629 category ===========
# ======== Leanring 630 category ===========
# ======== Leanring 631 category ===========
# ======== Leanring 632 category ===========
# ======== Leanring 633 category ===========
# ======== Leanring 634 category ===========
# ======== Leanring 635 category ===========
# ======== Leanring 636 category ===========
# ======== Leanring 637 category ===========
# ======== Leanring 638 category ===========
# ======== Leanring 639 category ===========
# ======== Leanring 640 category ===========
# ======== Leanring 641 category ===========
# ======== Leanring 642 category ===========
# ======== Leanring 643 category ===========
# ======== Leanring 644 category ===========
# ======== Leanring 645 category ===========
# ======== Leanring 646 category ===========
# ======== Leanring 647 category ===========
# ======== Leanring 648 category ===========
# ======== Leanring 649 category ===========
# ======== Leanring 650 category ===========
# ======== Leanring 651 category ===========
# ======== Leanring 652 category ===========
# ======== Leanring 653 category ===========
# ======== Leanring 654 category ===========
# ======== Leanring 655 category ===========
# ======== Leanring 656 category ===========
# ======== Leanring 657 category ===========
# ======== Leanring 658 category ===========
# ======== Leanring 659 category ===========
# ======== Leanring 660 category ===========
# ======== Leanring 661 category ===========
# ======== Leanring 662 category ===========
# ======== Leanring 663 category ===========
# ======== Leanring 664 category ===========
# ======== Leanring 665 category ===========
# ======== Leanring 666 category ===========
# ======== Leanring 667 category ===========
# ======== Leanring 668 category ===========
# ======== Leanring 669 category ===========
# ======== Leanring 670 category ===========
# ======== Leanring 671 category ===========
# ======== Leanring 672 category ===========
# ======== Leanring 673 category ===========
# ======== Leanring 674 category ===========
# ======== Leanring 675 category ===========
# ======== Leanring 676 category ===========
# ======== Leanring 677 category ===========
# ======== Leanring 678 category ===========
# ======== Leanring 679 category ===========
# ======== Leanring 680 category ===========
# ======== Leanring 681 category ===========
# ======== Leanring 682 category ===========
# ======== Leanring 683 category ===========
# ======== Leanring 684 category ===========
# ======== Leanring 685 category ===========
# ======== Leanring 686 category ===========
# ======== Leanring 687 category ===========
# ======== Leanring 688 category ===========
# ======== Leanring 689 category ===========
# ======== Leanring 690 category ===========
# ======== Leanring 691 category ===========
# ======== Leanring 692 category ===========
# ======== Leanring 693 category ===========
# ======== Leanring 694 category ===========
# ======== Leanring 695 category ===========
# ======== Leanring 696 category ===========
# ======== Leanring 697 category ===========
# ======== Leanring 698 category ===========
# ======== Leanring 699 category ===========
# ======== Leanring 700 category ===========
# ======== Leanring 701 category ===========
# ======== Leanring 702 category ===========
# ======== Leanring 703 category ===========
# ======== Leanring 704 category ===========
# ======== Leanring 705 category ===========
# ======== Leanring 706 category ===========
# ======== Leanring 707 category ===========
# ======== Leanring 708 category ===========
# ======== Leanring 709 category ===========
# ======== Leanring 710 category ===========
# ======== Leanring 711 category ===========
# ======== Leanring 712 category ===========
# ======== Leanring 713 category ===========
# ======== Leanring 714 category ===========
# ======== Leanring 715 category ===========
# ======== Leanring 716 category ===========
# ======== Leanring 717 category ===========
# ======== Leanring 718 category ===========
# ======== Leanring 719 category ===========
# ======== Leanring 720 category ===========
# ======== Leanring 721 category ===========
# ======== Leanring 722 category ===========
# ======== Leanring 723 category ===========
# ======== Leanring 724 category ===========
# ======== Leanring 725 category ===========
# ======== Leanring 726 category ===========
# ======== Leanring 727 category ===========
# ======== Leanring 728 category ===========
# ======== Leanring 729 category ===========
# ======== Leanring 730 category ===========
# ======== Leanring 731 category ===========
# ======== Leanring 732 category ===========
# ======== Leanring 733 category ===========
# ======== Leanring 734 category ===========
# ======== Leanring 735 category ===========
# ======== Leanring 736 category ===========
# ======== Leanring 737 category ===========
# ======== Leanring 738 category ===========
# ======== Leanring 739 category ===========
# ======== Leanring 740 category ===========
# ======== Leanring 741 category ===========
# ======== Leanring 742 category ===========
# ======== Leanring 743 category ===========
# ======== Leanring 744 category ===========
# ======== Leanring 745 category ===========
# ======== Leanring 746 category ===========
# ======== Leanring 747 category ===========
# ======== Leanring 748 category ===========
# ======== Leanring 749 category ===========
# ======== Leanring 750 category ===========
# ======== Leanring 751 category ===========
# ======== Leanring 752 category ===========
# ======== Leanring 753 category ===========
# ======== Leanring 754 category ===========
# ======== Leanring 755 category ===========
# ======== Leanring 756 category ===========
# ======== Leanring 757 category ===========
# ======== Leanring 758 category ===========
# ======== Leanring 759 category ===========
# ======== Leanring 760 category ===========
# ======== Leanring 761 category ===========
# ======== Leanring 762 category ===========
# ======== Leanring 763 category ===========
# ======== Leanring 764 category ===========
# ======== Leanring 765 category ===========
# ======== Leanring 766 category ===========
# ======== Leanring 767 category ===========
# ======== Leanring 768 category ===========
# ======== Leanring 769 category ===========
# ======== Leanring 770 category ===========
# ======== Leanring 771 category ===========
# ======== Leanring 772 category ===========
# ======== Leanring 773 category ===========
# ======== Leanring 774 category ===========
# ======== Leanring 775 category ===========
# ======== Leanring 776 category ===========
# ======== Leanring 777 category ===========
# ======== Leanring 778 category ===========
# ======== Leanring 779 category ===========
# ======== Leanring 780 category ===========
# ======== Leanring 781 category ===========
# ======== Leanring 782 category ===========
# ======== Leanring 783 category ===========
# ======== Leanring 784 category ===========
# ======== Leanring 785 category ===========
# ======== Leanring 786 category ===========
# ======== Leanring 787 category ===========
# ======== Leanring 788 category ===========
# ======== Leanring 789 category ===========
# ======== Leanring 790 category ===========
# ======== Leanring 791 category ===========
# ======== Leanring 792 category ===========
# ======== Leanring 793 category ===========
# ======== Leanring 794 category ===========
# ======== Leanring 795 category ===========
# ======== Leanring 796 category ===========
# ======== Leanring 797 category ===========
# ======== Leanring 798 category ===========
# ======== Leanring 799 category ===========
# ======== Leanring 800 category ===========
# ======== Leanring 801 category ===========
# ======== Leanring 802 category ===========
# ======== Leanring 803 category ===========
# ======== Leanring 804 category ===========
# ======== Leanring 805 category ===========
# ======== Leanring 806 category ===========
# ======== Leanring 807 category ===========
# ======== Leanring 808 category ===========
# ======== Leanring 809 category ===========
# ======== Leanring 810 category ===========
# ======== Leanring 811 category ===========
# ======== Leanring 812 category ===========
# ======== Leanring 813 category ===========
# ======== Leanring 814 category ===========
# ======== Leanring 815 category ===========
# ======== Leanring 816 category ===========
# ======== Leanring 817 category ===========
# ======== Leanring 818 category ===========
# ======== Leanring 819 category ===========
# ======== Leanring 820 category ===========
# ======== Leanring 821 category ===========
# ======== Leanring 822 category ===========
# ======== Leanring 823 category ===========
# ======== Leanring 824 category ===========
# ======== Leanring 825 category ===========
# ======== Leanring 826 category ===========
# ======== Leanring 827 category ===========
# ======== Leanring 828 category ===========
# ======== Leanring 829 category ===========
# ======== Leanring 830 category ===========
# ======== Leanring 831 category ===========
# ======== Leanring 832 category ===========
# ======== Leanring 833 category ===========
# ======== Leanring 834 category ===========
# ======== Leanring 835 category ===========
# ======== Leanring 836 category ===========
# ======== Leanring 837 category ===========
# ======== Leanring 838 category ===========
# ======== Leanring 839 category ===========
# ======== Leanring 840 category ===========
# ======== Leanring 841 category ===========
# ======== Leanring 842 category ===========
# ======== Leanring 843 category ===========
# ======== Leanring 844 category ===========
# ======== Leanring 845 category ===========
# ======== Leanring 846 category ===========
# ======== Leanring 847 category ===========
# ======== Leanring 848 category ===========
# ======== Leanring 849 category ===========
# ======== Leanring 850 category ===========
# ======== Leanring 851 category ===========
# ======== Leanring 852 category ===========
# ======== Leanring 853 category ===========
# ======== Leanring 854 category ===========
# ======== Leanring 855 category ===========
# ======== Leanring 856 category ===========
# ======== Leanring 857 category ===========
# ======== Leanring 858 category ===========
# ======== Leanring 859 category ===========
# ======== Leanring 860 category ===========
# ======== Leanring 861 category ===========
# ======== Leanring 862 category ===========
# ======== Leanring 863 category ===========
# ======== Leanring 864 category ===========
# ======== Leanring 865 category ===========
# ======== Leanring 866 category ===========
# ======== Leanring 867 category ===========
# ======== Leanring 868 category ===========
# ======== Leanring 869 category ===========
# ======== Leanring 870 category ===========
# ======== Leanring 871 category ===========
# ======== Leanring 872 category ===========
# ======== Leanring 873 category ===========
# ======== Leanring 874 category ===========
# ======== Leanring 875 category ===========
# ======== Leanring 876 category ===========
# ======== Leanring 877 category ===========
# ======== Leanring 878 category ===========
# ======== Leanring 879 category ===========
# ======== Leanring 880 category ===========
# ======== Leanring 881 category ===========
# ======== Leanring 882 category ===========
# ======== Leanring 883 category ===========
# ======== Leanring 884 category ===========
# ======== Leanring 885 category ===========
# ======== Leanring 886 category ===========
# ======== Leanring 887 category ===========
# ======== Leanring 888 category ===========
# ======== Leanring 889 category ===========
# ======== Leanring 890 category ===========
# ======== Leanring 891 category ===========
# ======== Leanring 892 category ===========
# ======== Leanring 893 category ===========
# ======== Leanring 894 category ===========
# ======== Leanring 895 category ===========
# ======== Leanring 896 category ===========
# ======== Leanring 897 category ===========
# ======== Leanring 898 category ===========
# ======== Leanring 899 category ===========
# ======== Leanring 900 category ===========
# ======== Leanring 901 category ===========
# ======== Leanring 902 category ===========
# ======== Leanring 903 category ===========
# ======== Leanring 904 category ===========
# ======== Leanring 905 category ===========
# ======== Leanring 906 category ===========
# ======== Leanring 907 category ===========
# ======== Leanring 908 category ===========
# ======== Leanring 909 category ===========
# ======== Leanring 910 category ===========
# ======== Leanring 911 category ===========
# ======== Leanring 912 category ===========
# ======== Leanring 913 category ===========
# ======== Leanring 914 category ===========
# ======== Leanring 915 category ===========
# ======== Leanring 916 category ===========
# ======== Leanring 917 category ===========
# ======== Leanring 918 category ===========
# ======== Leanring 919 category ===========
# ======== Leanring 920 category ===========
# ======== Leanring 921 category ===========
# ======== Leanring 922 category ===========
# ======== Leanring 923 category ===========
# ======== Leanring 924 category ===========
# ======== Leanring 925 category ===========
# ======== Leanring 926 category ===========
# ======== Leanring 927 category ===========
# ======== Leanring 928 category ===========
# ======== Leanring 929 category ===========
# ======== Leanring 930 category ===========
# ======== Leanring 931 category ===========
# ======== Leanring 932 category ===========
# ======== Leanring 933 category ===========
# ======== Leanring 934 category ===========
# ======== Leanring 935 category ===========
# ======== Leanring 936 category ===========
# ======== Leanring 937 category ===========
# ======== Leanring 938 category ===========
# ======== Leanring 939 category ===========
# ======== Leanring 940 category ===========
# ======== Leanring 941 category ===========
# ======== Leanring 942 category ===========
# ======== Leanring 943 category ===========
# ======== Leanring 944 category ===========
# ======== Leanring 945 category ===========
# ======== Leanring 946 category ===========
# ======== Leanring 947 category ===========
# ======== Leanring 948 category ===========
# ======== Leanring 949 category ===========
# ======== Leanring 950 category ===========
# ======== Leanring 951 category ===========
# ======== Leanring 952 category ===========
# ======== Leanring 953 category ===========
# ======== Leanring 954 category ===========
# ======== Leanring 955 category ===========
# ======== Leanring 956 category ===========
# ======== Leanring 957 category ===========
# ======== Leanring 958 category ===========
# ======== Leanring 959 category ===========
# ======== Leanring 960 category ===========
# ======== Leanring 961 category ===========
# ======== Leanring 962 category ===========
# ======== Leanring 963 category ===========
# ======== Leanring 964 category ===========
# ======== Leanring 965 category ===========
# ======== Leanring 966 category ===========
# ======== Leanring 967 category ===========
# ======== Leanring 968 category ===========
# ======== Leanring 969 category ===========
# ======== Leanring 970 category ===========
# ======== Leanring 971 category ===========
# ======== Leanring 972 category ===========
# ======== Leanring 973 category ===========
# ======== Leanring 974 category ===========
# ======== Leanring 975 category ===========
# ======== Leanring 976 category ===========
# ======== Leanring 977 category ===========
# ======== Leanring 978 category ===========
# ======== Leanring 979 category ===========
# ======== Leanring 980 category ===========
# ======== Leanring 981 category ===========
# ======== Leanring 982 category ===========
# ======== Leanring 983 category ===========
# ======== Leanring 984 category ===========
# ======== Leanring 985 category ===========
# ======== Leanring 986 category ===========
# ======== Leanring 987 category ===========
# ======== Leanring 988 category ===========
# ======== Leanring 989 category ===========
# ======== Leanring 990 category ===========
# ======== Leanring 991 category ===========
# ======== Leanring 992 category ===========
# ======== Leanring 993 category ===========
# ======== Leanring 994 category ===========
# ======== Leanring 995 category ===========
# ======== Leanring 996 category ===========
# ======== Leanring 997 category ===========
# ======== Leanring 998 category ===========
# ======== Leanring 999 category ===========

# %%
# visualize results
index = 9
category = list(output_dict.keys())[index]
displays_image_list(output_dict[category], print_number=NUM_CLUSTER, num_per_line=15)
